# %%
from bs4 import BeautifulSoup

from splinter import Browser
from splinter.exceptions import ElementDoesNotExist

# %%
# URL of page to be scraped
url = 'https://www.barnesandnoble.com/bookSearch/isbnInquiry.asp?isbn=1467741876'

# %%
executable_path = {'executable_path': './chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url) 
browser

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
soup.prettify
# Out:
# <bound method Tag.prettify of <!-- Below forEach block added to generate redirectURL for productCategories, it's used in every PDP page --><!-- 	Below block checks the value of lastLevelCategory i.e. leaf node with corresponding productCategory --><!--  This if block is introduced to check if lastLevelCategory doesn't match productCategories' name though it's not empty hence setting first URL --><!DOCTYPE html>
# ...

# %%
bn_price_results = soup.find_all('span', class_='price current-price ml-0')
bn_price_results
# Out:
# [<span class="price current-price ml-0" id="pdp-cur-price"><sup>$</sup>38.65</span>]

# %%
bn_price = bn_price_results[0].text
bn_price
# Out:
# '$38.65'

# %%
list_price_results = soup.find_all('input', id='listPrice')
list_price_results
# Out:
# [<input id="listPrice" type="hidden" value="38.65"/>]

# %%
list_price = list_price_results[0]['value']
list_price
# Out:
# '38.65'

# %%
soup.find_all('input', id='listPrice')[0]['value']
# Out:
# '38.65'

# %%
soup.find_all('s', class_='old-price')
# Out:
# []
